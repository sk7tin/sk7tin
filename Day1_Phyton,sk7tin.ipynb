# %%
имя = "Виткор"

# %%
фамилия = "Скутин"

# %%
возвраст = 27

# %%
энергия = 7

# %%
print("Полное имя:", имя , фамилия)
# Out:
# Полное имя: Виткор Скутин

# %%
print("Возвраст в 2026 году:", возвраст, "лет")
# Out:
# Возвраст в 2026 году: 27 лет

# %%
print("Моё число судьбы:", энергия)
# Out:
# Моё число судьбы: 7

# %%
print("Тест расчёта:", 13+7, "(энергия 13+7)")
# Out:
# Тест расчёта: 20 (энергия 13+7)
