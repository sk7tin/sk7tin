# %%
имя = input("Как тебя зовут? ")
print("Привет,", имя, "! Это День 2.")
# Out:
# Как тебя зовут?  Виктор
# Привет, Виктор ! Это День 2.

# %%
возраст = int(input("Сколько тебе лет?"))

if возраст >= 18:
    print("Ты взрослый - можно в клуб и в AI-разработку😎 ")
else:
    print("Ты еще молод, подрасти немного и мы с тобой встретимся снова😎")
# Out:
# Сколько тебе лет? 27
# Ты взрослый - можно в клуб и в AI-разработку😎

# %%
день = int(input("Введи день рождения (1-31): "))
месяц = int(input("Введи месяц рождения (1-12): "))
сумма = день + месяц 
число = сумма % 9
if число == 0:
    число = 9
print("Твое простое число судьбы:", число)
if число == 7:
    print("7 - как у sk7tin! Искатель истины и мистик ✨")
elif число == 3:
    print("3 - творчество и общение. Ты можешь вдохновлять!")
else:
    print("Интересное число.Продолжай эксперементировать!")
